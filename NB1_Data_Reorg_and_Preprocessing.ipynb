# %%
import os
import re
import pandas as pd
from tqdm import tqdm
from unidecode import unidecode
from collections import defaultdict

# %%
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_csv("annotations_metadata.csv")
df.head(5)
# Out:
#       file_id  user_id  subforum_id  num_contexts   label
# 0  12834217_1  572066   1346         0             noHate
# 1  12834217_2  572066   1346         0             noHate
# 2  12834217_3  572066   1346         0             noHate
# 3  12834217_4  572066   1346         0             hate
# 4  12834217_5  572066   1346         0             noHate

# %% [markdown]
# ## Read in posts as a csv column

# %%
post_list = []
for idx, row in df.iterrows():
    with open("{}/{}.txt".format("all_files", row["file_id"])) as f:
        post_list.append(f.read().strip())

# %%
df["post"] = post_list

# %%
df["comment_id"] = [int(x.split("_")[0]) for x in df.file_id.tolist()]
df["sentence_num"] = [int(x.split("_")[1]) for x in df.file_id.tolist()]

# %% [markdown]
# ## What do some of the hate speech comments look like?

# %%
df[df["label"] == "hate"][["file_id", "post", "num_contexts"]].head(20)
# Out:
#         file_id  \
# 3    12834217_4
# 10   12834493_1
# 21   12849464_3
# 22   12849464_4
# 31   12855154_1
# 42   12860820_1
# 46   12869018_3
# 59   12883101_1
# 62   12904919_1
# 70   13061184_1
# 71   13061184_2
# 104  13293414_1
# 108  13391410_1
# 110  13401474_2
# 111  13401474_3
# 112  13406897_1
# 113  13406897_2
# 114  13406897_3
# 117  13422115_2
# 120  13434590_2
#
#                                                                                                                                                                                                     post  \
# 3    Click below for a FREE download of a colorfully illustrated 132 page e-book on the Zionist-engineered INTENTIONAL destruction of Western civilization .
# 10   She may or may not be a Jew but she 's certainly stupid , she seems to think the Blacks wo n't kill her alongside every other White they can get their dirty hands on , what a muppet !
# 21   I 've always considered teaching as one of the professions I would like to get into , but not in a neighbourhood like that ... never. kids like that disgust me .
# 22   And the sad thing is the white students at those schools will act like that too .
# 31   Their gods often had pale skin and blue eyes but I suppose literacy is n't valued highly by their cultural intelligencia .
# 42   Greece need a man like Adolf Hitler and now is the perfect time to start a national political movement to free Your country from the zionist bankers
# 46   He is a pathetic little chimp .
# 59   Try El Paso Texas Soo much mudd invasion that the river is the same color as those playing/crossing in it .. year round !
# 62   Here is a video of the event that is worth watching just to see a beautiful White lady screaming `` scum , scum , scum , f * * * ing scum !!! '' at the muslim filth .
# 70   I suppose the concept of a male cow and a female cow producing MORE cows , and the repeating process is too much for them to understand .
# 71   May they all get mad cow disease .
# 104  Nevermind, found the new page Knew it had to be a groid .... any report of rape ?
# 108  they act as if negros with aids should have the right to reproduce when they will die off and have no way to take care of the kid I cant believe that they are doing this by the millions its crazy
# 110  I hope they all starve .
# 111  No white person should send a single penny or lift a single finger to help them .
# 112  He's a retarded feral negro ( yes , feral humans who cannot talk occasionally pop up , having been abandoned as children. ) .
# 113  He walks upright , and has human arms and legs .
# 114  I 've seen negroes who look ( and undoubtedly act ) like him .
# 117  I will respond until Armenian scum will stop
# 120  Where a white woman can go about in public and not fear assault by muds .
#
#      num_contexts
# 3    0
# 10   0
# 21   1
# 22   1
# 31   0
# 42   0
# 46   1
# 59   4
# 62   0
# 70   1
# 71   1
# 104  1
# 108  1
# 110  2
# 111  2
# 112  0
# 113  0
# 114  0
# 117  0
# 120  0

# %% [markdown]
# ## Convert label column to numeric

# %%
df["num_label"] = [1 if label == "hate" else 0 for label in df["label"].tolist()]

# %% [markdown]
# ## Remove Extra Columns

# %%
df = df.drop(["label"], axis="columns")

# %% [markdown]
# ## Class Distribution:
# - Dataset is mostly no_hate... may need to balance it later

# %%
df.groupby("num_label")["file_id"].count()/len(df.index)
# Out:
# num_label
# 0    0.890716
# 1    0.109284
# Name: file_id, dtype: float64

# %%
# Ex: find_examples_in_text(train_df["posts"].tolist(), [r":[a-zA-Z]+:(?=[:\s])"], padding=5, num_examples=20)
def find_examples_in_text(documents, words, num_examples=1, padding=100):
    curr_examples = 0
    examples = defaultdict(lambda: defaultdict(lambda: defaultdict(str)))
    for word in words:
        print("Examples of {}".format(word))
        for doc_idx, document in enumerate(documents):
            word_idx = re.search(word, document)
            if word_idx:
                # print(word_idx)
                examples[word][doc_idx][word_idx] = document[max(word_idx.start()-100, 0):min(word_idx.end()+100, len(document))]
                curr_examples += 1
                if curr_examples >= num_examples:
                    break
    return examples

# %%
find_examples_in_text(df.post.tolist(), [r"\*"], num_examples=50)
# Out:
# Examples of \*
# defaultdict(<function __main__.find_examples_in_text.<locals>.<lambda>()>,
#             {'\\*': defaultdict(<function __main__.find_examples_in_text.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {62: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(123, 124), match='*'>: "event that is worth watching just to see a beautiful White lady screaming `` scum , scum , scum , f * * * ing scum !!! '' at the muslim filth ."}),
#                           76: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(0, 1), match='*'>: '* Unsubscribed * Off to the SA threads .'}),
#                           92: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(21, 22), match='*'>: "Excellent Article !! * * * * * Why Were n't They In Jail ?"}),
#                           157: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(6, 7), match='*'>: '2.0 ) * Does contain alot of profanity , so you have been forewarned *'}),
#                           241: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(214, 215), match='*'>: 'Deputies After Finding Note POSTED : Monday , March 8 , 2010 UPDATED : 9 : 42 am EST March 9 , 2010 * * * Pedophile Alert * * * Robert Bennett. http://www.clickorlando.com/educatio...82/detail.html'}),
#                           260: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(116, 117), match='*'>: 'itten th epost for last summer but had to cancel my trip ... so it is 2005 !!! ok every body cool ? * L * Shann 2508'}),
#                           348: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(21, 22), match='*'>: 'They are stunning !! * KISS * 2056'}),
#                           400: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(11, 12), match='*'>: 'They all p * * * * d off and stayed up their end with that stupid look on their faces .'}),
#                           533: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(103, 104), match='*'>: ' i definitly know what your going through. i am a reserve officer in my town just so i can bust the * * * * * * crack dealers. i have no better enjoyment than to watch one squirm before he is sent up t'}),
#                           548: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(39, 40), match='*'>: 'Thanks to all responses , Deathstar 69 * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * * Mod Note '}),
#                           591: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(265, 266), match='*'>: "st shirt on and the other had a big swazi on his lower back and it did n't seem like he was getting * * * * for it in public , then I saw a few other 's on later trip 's , you 're not alone comrade ."}),
#                           786: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(113, 114), match='*'>: "se friends online , and they think it 's pretty funny that our countries are letting themselves get * * * * ed by bull * * * * ."}),
#                           996: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(92, 93), match='*'>: "My new word o ' the week ( which has somehow become the word o ' two weeks ) : torpid : tor * pid adj : 1 ) Dormant ; hibernating ."}),
#                           1025: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(13, 14), match='*'>: 'This is bull * * * * !'}),
#                           1067: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(71, 72), match='*'>: "I seriously ca n't figure what group I belong to ... any suggestions ? * The Mighty Sisto *"}),
#                           1102: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(93, 94), match='*'>: 'yea i thought so when i saw a episode they had a klanmen on there and he was calling jerry a * * * * ing jew lol'}),
#                           1203: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(7, 8), match='*'>: 'Do ` F * ck with our families , buckwheat !!'}),
#                           1218: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(115, 116), match='*'>: "d walk back into my H.S. when it starts Monday and get on the P.A. system and say I want to tie all * * * * * * s to the back of my car and drag them across the ground till they die , and then say I 'm"}),
#                           1338: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(162, 163), match='*'>: ' Rus shacking up with some Islamic mud from that fithy , impoverished , and godforsaken mountainous * * * * hole !'}),
#                           1417: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(29, 30), match='*'>: 'Looks like Dennys is on my s * it list now .'}),
#                           1418: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(57, 58), match='*'>: 'I would love two minutes alone in a room with whatever s * it for brains faggots came up with that advertisement .'}),
#                           1440: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(27, 28), match='*'>: 'www.immigrationcontrol.org * * * * the E U its the Soviet system but much worse .'}),
#                           1593: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(0, 1), match='*'>: '**** off bulgar turkic peice of * * * * and * * * * ustasha KOSOVO belongs to SERBİA get used to it h'}),
#                           1675: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(131, 132), match='*'>: 'nd other Western European countries nazis are banned from everywhere , but in Bulgaria u can live , * * * * gypsies and some * * * * * * s/not much = 15-20 ppl in my town / u can dress like skin and be'}),
#                           1790: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(112, 113), match='*'>: " little television and what little I do watch sure as hell wo n't be spent as a study of the common * * * * * * s psyche ."}),
#                           2157: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(15, 16), match='*'>: "Or try yelling * * * * the nigs ya 'll get suspended , jumped and hopefully some new wn friends or ya 'll die trying"}),
#                           2173: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(102, 103), match='*'>: 'only wore it once to school and they told me either never wear again or be expeled I chose to never * ahem * show them again .'}),
#                           2175: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(35, 36), match='*'>: "But be careful what you say , some * * * * * * or anti-White supremacism person might say `` Ca n't we get over our petty differences li"}),
#                           2198: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(73, 74), match='*'>: 'Dyeing your hair is the right thing to do. : attack GO AND RUN ME OVER A * * * * * *'}),
#                           2226: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(60, 61), match='*'>: "It 's another way to destroy Hungarians on top of promoting * * * * * * music , race mixing and pornography ."}),
#                           2249: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(8, 9), match='*'>: "`` Oh s * * t , '' without looking , `` I hit one of their cars and now I am going to die ! '' , but to my re"}),
#                           2322: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(122, 123), match='*'>: 'id liberals are , even after being nearly murdered for being white Mr. Begley is still a ridiculous * * * * * * -loving fool .'}),
#                           2481: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(69, 70), match='*'>: "`` Nargaroth - The Day Burzum Killed Mayhem '' heheh ) either though * shrug * Scandinavia really is a black metal heaven but there 're many great bands on the outside wh"}),
#                           2506: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(19, 20), match='*'>: 'that is absolutely * * * * ing unbelievable.they can just go route one now.no more messing about going through europe.in'}),
#                           2515: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(4, 5), match='*'>: 'BULL****!'}),
#                           2598: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(49, 50), match='*'>: "Sooner or later the black one will say `` mother * * * * er '' or `` madick '' ."}),
#                           2636: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(13, 14), match='*'>: 'Anti-White C * * T.'}),
#                           3017: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(2, 3), match='*'>: '3 * 9 * 50 scope .'}),
#                           3170: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(162, 163), match='*'>: "aily basis - let 's take a look at some of their ritual practices : [ IMG ] http://torture.justsick * * * * .com/wp-content/uploads/2007/10/butter-electric-chair-botched.jpg [ /IMG ] Another sacrifical"}),
#                           3526: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(8, 9), match='*'>: "Every f * cking school child knows that the Globe is round , only total PIZDAS do n't ."}),
#                           3670: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(15, 16), match='*'>: '11000 euro !?! * * * * ing scum ! i wonder if anyone would get anything if they set themselves up in a polish area a'}),
#                           3708: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(55, 56), match='*'>: 'It only took Labour ten years to bring more immigrants * cough * invaders , here than had ever migrated here in the last 5 thousand years .'}),
#                           3945: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(111, 112), match='*'>: ' for anyone downloading the petition ......... Remember to put your paper setting on 8 1/2 X 14 for * * * LEGAL * * * documents. petition download Good luck friends , Gordon _ Inc.'}),
#                           4077: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(33, 34), match='*'>: 'YouTube - & quot ; Ð Ð ? Ð ¨ Ð Ð * Ð # Ð ® Ð cents Ð ¬ Ð Ð Ð Ð * Ð Ð Ð Ð Ð ¬ Ð ¦ Ð ... & quot ;'}),
#                           4320: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(22, 23), match='*'>: "They carry those `` n * * * * r brushes '' and sag their pants ."}),
#                           4361: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(81, 82), match='*'>: "`` I wanna look just like that skinny white lady , just black and beautiful . '' * shakes his head *"}),
#                           4404: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(52, 53), match='*'>: 'You counter your own post with your own words you f * * * * * g idiot'}),
#                           4462: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(6, 7), match='*'>: 'Oh my * * * * ing god !'}),
#                           4608: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(27, 28), match='*'>: 'I hate the dramas and bull * * * * like this .'}),
#                           4689: defaultdict(str,
#                                       {<_sre.SRE_Match object; span=(9, 10), match='*'>: 'Piece of * * * * deserves to be shot .'})})})

# %% [markdown]
# ## Text Preprocessing
# The text looks like it has already been run through a tokenizer. For now, we should just do some basic preprocessing.  I'll check off the stuff that I actually did.  The other stuff can be recommendations for future:
#
# - [x] Try to normalize some of the links (they have already been preprocessed unfortunately so it will be a bit harder)
# - [ ] Surround capitalized words with "_caps_ word _caps_"
# - [x] Convert Numbers to "_number_"
# - [ ] Each post is labelled commendID_sentenceNumber.txt - Some sentences however may only be toxic due to the surrounding ones.  Append the previous and current sentence to each post
# - [ ] The incoming comments have already been tokenized (which sucks because their tokenizer is not great).  May need to undo this and re-tokenize
# - [x] The posts have also either been run through a profanity filter, or the site itself does not allow profanity, this has then been retokenized
# - [x] Standardize repeated characters

# %%
def replace_word_dates(text, replace_str="_date_"):
    short_month_regex = r"([Jj]an|[Ff]eb|[Mm]ar|[Aa]pr|[Mm]a|[Jj]un|[Jj]ul|[Aa]ug|[Ss](ep|ept)|[Oo]ct|[Nn]ov|[Dd]ec)\.?"
    long_month_regex = r"([Jj]anuary|[Ff]ebuary|[Mm]arch|[Aa]pril|[Mm]ay|[Jj]une|[Jj]uly|[Aa]ugust|[Ss]eptember|[Oo]ctober|[Nn]ovember|[Dd]ecember)"
    day_regex = r"([1-2][0-9]|3[01]|0?[1-9])(th|st)?(,| ,)?"
    space_regexes = [r" ", r"\s?-\s?"]
    # 1900s and 2000s
    year_regex = r"(1[0-9]{3}|20[0-9]{2}|'?[0-9]{2})"
    for space_regex in space_regexes:
        final_regex = r"({sm}|{lm})({sp}{day})?{sp}{year}".format(sm=short_month_regex, lm=long_month_regex, day=day_regex, sp=space_regex, year=year_regex)
        text = re.sub(final_regex, replace_str, text)
    return text

# %%
import nltk
nltk.download('wordnet')
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english", ignore_stopwords=True)
lemma = nltk.wordnet.WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package wordnet to /home/michael/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
post_list = df.post.tolist()
preprocessed_posts = []
for idx, post in enumerate(tqdm(df.post.tolist())):
    post = unidecode(post)
    post = replace_word_dates(post)
    # Replace File Links: http://www.mediafire.com/download/96fg6ft02lyfruz/Booklet _ White _ YT _ Comment _ ( Hyperlinked ) .txt
    post = re.sub(r"https?:\/\/([a-zA-Z0-9_\-\/%\+]\s?|[a-zA-Z0-9]\.[a-zA-Z0-9])+(\( Hyperlinked \) |\( Hyperlinked-Back-Up % 5D)?\.(txt|pdf|docx)", " _file_link_ ", post)
    # Replace Youtube Links: http://www.youtube.com/watch ? v = _ 8hg254ALpM
    post = re.sub(r"https?:\/\/(www\.)?(youtube\.com\/watch \? v = _ [a-zA-Z0-9_]+)", " _youtube_link_ ", post)
    # Replace Other Links: http://trutube.tv/video/14247/The-Zionist-Attack-on-Western-Civilization-Pages-1-33-Part-1-of-4-Banned-from-YouTubeNotepadPromotionalYouTubeComment
    post = re.sub(r"https?:\/\/([a-zA-Z0-9_\-\/\.](?!ttp))+", " _other_link_ ", post)
    # Replace Numbers: 
    post = re.sub(r"(?<=\s)([0-9]+\.?[0-9]*|[0-9]{1,3},([0-9]{3})+)(?=\s)", " _number_ ", post)
    # Repeated !
    post = re.sub(r"!{2,}", " _repeatexc_ ", post)
    # Repeated ?
    post = re.sub(r"\?{2,}", " _repeatq_ ", post)
    # Repeated .
    post = re.sub(r"\.{4,}", " ... ", post)
    # Censor in middle of word: s**t, s*t, etc
    post = re.sub(r"(?<=\s)[a-zA-Z]\s(\*\s){1,}[a-z]*", " _censored_ ", post)
    # Censor first part of word: ***ing, ***ed
    post = re.sub(r"(?<!(\s[a-zA-Z]|(\s|[0-9])[0-9]|\s\*)\s)(\*\s?){2,}(ing|hole|ed|\!|\?|\.(?![a-z]))", " _censored_ ", post)
    # Remove Dashes
    post = re.sub(r"-", " ", post)
    # Repeated *
    post = re.sub(r"(?<=\S)\s(\*\s){2,}", " _repeatstar_ ", post)
    # Remove Commas
    post = re.sub(r",", " ", post)
    # Remove Quotation
    post = re.sub(r"'", "", post)
    # Slashes
    post = re.sub(r"\/", " / ", post)
    # Remove `:
    post = re.sub(r"`", " ", post)
    # Remove Excess Spaces
    post = re.sub(r'\s+', ' ', post).strip()
    # Stem?
    post = ' '.join([stemmer.stem(x) for x in post.split(" ")])
    #post = ' '.join([lemma.lemmatize(x) for x in post.split(" ")])
    # Lower Case
    final_post = post.lower()
    preprocessed_posts.append(final_post)
# Out:
# 100%|██████████| 10944/10944 [00:01<00:00, 7153.22it/s]

# %%
df["preprocessed_post"] = preprocessed_posts

# %%
df[["post", "preprocessed_post", "num_label"]].head(20)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     post  \
# 0   As of March 13th , 2014 , the booklet had been downloaded over 18,300 times and counting .
# 1   In order to help increase the booklets downloads , it would be great if all Stormfronters who had YouTube accounts , could display the following text in the description boxes of their uploaded YouTube videos .
# 2   ( Simply copy and paste the following text into your YouTube videos description boxes. )
# 3   Click below for a FREE download of a colorfully illustrated 132 page e-book on the Zionist-engineered INTENTIONAL destruction of Western civilization .
# 4   Click on the `` DOWNLOAD ( 7.42 MB ) '' green banner link .
# 5   Booklet updated on Feb. 14th , 2014 .
# 6   ( Now with over 18,300 Downloads. )
# 7   PDF file : http://www.mediafire.com/download/7p3p3goadvvqvsf/WNDebateBooklet_2-14-14.pdfMSWordfile:http://www.mediafire.com/download/psezkkk4d6a3wt1/WNDebateBooklet _ 2-14-14.docx Watch the 10 hour video version of `` The Zionist Attack on Western Civilization '' @ http://trutube.tv/video/14247/The-Zionist-Attack-on-Western-Civilization-Pages-1-33-Part-1-of-4-Banned-from-YouTubeNotepadPromotionalYouTubeComment:http://www.mediafire.com/download/96fg6ft02lyfruz/Booklet _ White _ YT _ Comment _ ( Hyperlinked ) .txt http://www.mediafire.com/download/zcn3wozjbwnezms/Booklet-White-YT-Comment- ( Hyperlinked-Back-Up % 5D.txt http://www.mediafire.com/download/9uyudq1yuxu1dur/Booklet+Comment+%28Firefox%29.txt2minutepromotionalBOOKLETvideo@http://www.youtube.com/watch ? v = _ 8hg254ALpM Are you interested in helping spread the booklet download link across the world ?
# 8   Then why not simply copy this text ( & links ) and paste it into the description box of your YouTube videos ?
# 9   Thank you in advance. : ) Download the youtube `` description box '' info text file below @ http://www.mediafire.com/download/dqhn1czprr17o21/Booklet-Description-Box _ Info.txt
# 10  She may or may not be a Jew but she 's certainly stupid , she seems to think the Blacks wo n't kill her alongside every other White they can get their dirty hands on , what a muppet !
# 11  Thank you for the info. i will deffinetly look into them .
# 12  I hope there is room for one more as i am very excited about this .
# 13  I just came across this piece of garbage .
# 14  Comments say she is from SA .
# 15  Warning : Graphic .
# 16  Die Antwoord - `` Cookie Thumper '' ( Official Video ) - YouTube
# 17  The whites are more in the range of 4.8 million .
# 18  I believe this can be higher since I 've read reports that especially whites in the Free State were not counted in the latest census .
# 19  Thank you for posting your story .
#
#                                                                                                                                                                                                                                                                                                preprocessed_post  \
# 0   as of _date_ the booklet had been download over _number_ time and count .
# 1   in order to help increas the booklet download it would be great if all stormfront who had youtub account could display the follow text in the descript box of their upload youtub video .
# 2   ( simpli copi and past the follow text into your youtub video descript boxes. )
# 3   click below for a free download of a color illustr _number_ page e book on the zionist engin intent destruct of western civil .
# 4   click on the download ( _number_ mb ) green banner link .
# 5   booklet updat on _date_ .
# 6   ( now with over _number_ downloads. )
# 7   pdf file : _file_link_ mswordfile: _file_link_ watch the _number_ hour video version of the zionist attack on western civil @ _other_link_ : _file_link_ _file_link_ _file_link_ 2minutepromotionalbookletvideo@ _youtube_link_ are you interest in help spread the booklet download link across the world ?
# 8   then why not simpli copi this text ( & link ) and past it into the descript box of your youtub video ?
# 9   thank you in advance. : ) download the youtub descript box info text file below @ _file_link_
# 10  she may or may not be a jew but she s certain stupid she seem to think the black wo nt kill her alongsid everi other white they can get their dirti hand on what a muppet !
# 11  thank you for the info. i will deffinet look into them .
# 12  i hope there is room for one more as i am very excit about this .
# 13  i just came across this piec of garbag .
# 14  comment say she is from sa .
# 15  warn : graphic .
# 16  die antwoord cooki thumper ( offici video ) youtub
# 17  the white are more in the rang of _number_ million .
# 18  i believ this can be higher sinc i ve read report that especi white in the free state were not count in the latest census .
# 19  thank you for post your stori .
#
#     num_label
# 0   0
# 1   0
# 2   0
# 3   1
# 4   0
# 5   0
# 6   0
# 7   0
# 8   0
# 9   0
# 10  1
# 11  0
# 12  0
# 13  0
# 14  0
# 15  0
# 16  0
# 17  0
# 18  0
# 19  0

# %% [markdown]
# ## Write Preprocessed Dataset to CSV

# %%
df.to_csv("preprocessed_posts.csv", index=False)
